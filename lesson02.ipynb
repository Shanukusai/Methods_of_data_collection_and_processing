# %% [markdown]
# # Урок 2. Парсинг HTML. BeautifulSoup, MongoDB

# %% [markdown]
# 1) Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     *Наименование вакансии
#     *Предлагаемую зарплату (отдельно мин. и отдельно макс. и отдельно валюта)
#     *Ссылку на саму вакансию
#     *Сайт откуда собрана вакансия
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

# %%
def parser_hh(soup):
    vacancy_block = soup.find('div',{'class':'vacancy-serp'})
    vacancy_list = vacancy_block.find_all('div',{'class':'vacancy-serp-item'})
    vacancies = []
    for vacancy in vacancy_list:
        vacancy_data = {}
        vacancy_name = vacancy.find('a', {'class':'bloko-link'}).getText()
        vacancy_link = vacancy.find('a',{'class':'bloko-link'})['href']
        vacancy_salary = vacancy.find('div', {'class':'vacancy-serp-item__sidebar'}).getText()
        if not vacancy_salary:
            vacancy_salary_min = None
            vacancy_salary_max = None
            vacancy_salary_currency = None
        else:
            vacancy_salary = vacancy_salary \
                            .replace(u'\xa0', u'')

            vacancy_salary = re.split(r'\s|-', vacancy_salary)

            if vacancy_salary[0] == 'до':
                vacancy_salary_min = None
                vacancy_salary_max = int(vacancy_salary[1])
            elif vacancy_salary[0] == 'от':
                vacancy_salary_min = int(vacancy_salary[1])
                vacancy_salary_max = None
            else:
                vacancy_salary_min = int(vacancy_salary[0])
                vacancy_salary_max = int(vacancy_salary[1])            

            vacancy_salary_currency = vacancy_salary[2]

        vacancy_data['name'] = vacancy_name
        vacancy_data['link'] = vacancy_link
        vacancy_data['salary_min'] = vacancy_salary_min
        vacancy_data['salary_max'] = vacancy_salary_max
        vacancy_data['salary_currency'] = vacancy_salary_currency
        vacancy_data['site'] = 'hh.ru'

        vacancies.append(vacancy_data)
    return vacancies

# %%
hh_main_link = 'https://hh.ru'
query = 'Python'
hh_page = 0
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:69.0) Gecko/20100101 Firefox/69.0'}

hh_vacancy_date = []

while True:
    hh_response = requests.get(hh_main_link + '/search/vacancy?text=' + query + '&page=' + str(hh_page), headers=headers).text
    hh_soup = bs(hh_response,'lxml')
    hh_vacancy_date = hh_vacancy_date + parser_hh(hh_soup)
    hh_page += 1
    if hh_soup.find('a',{'class':'HH-Pager-Controls-Next'}) is None:
        break

# %%
def parser_sj(soup, main_link):
#     vacancy_block = soup.find('div',{'class':'display: block;'})
#     vacancy_list = vacancy_block.find_all('div',{'class':'f-test-vacancy-item'})
    vacancy_list = soup.find_all('div',{'class':'f-test-vacancy-item'})
    vacancies = []
    for vacancy in vacancy_list:
        vacancy_data = {}
        vacancy_name = vacancy.find('a', {'class':'icMQ_'}).getText()
        vacancy_link = main_link + vacancy.find('a',{'class':'icMQ_'})['href']    
        vacancy_salary = vacancy.find('span', {'class':'f-test-text-company-item-salary'}).findChildren()
        if not vacancy_salary or vacancy_salary[-1].getText() == 'По договорённости':
            vacancy_salary_min = None
            vacancy_salary_max = None
            vacancy_salary_currency = None
        else:
            vacancy_salary_currency = vacancy_salary[-4].getText().replace(u'\xa0', u' ').split(' ')[-1]
            is_check_sarary = vacancy.find('span', {'class': 'f-test-text-company-item-salary'}) \
                                                .getText() \
                                                .replace(u'\xa0', u' ') \
                                                .split(' ', 1)[0]
            if is_check_sarary == 'до' or len(vacancy_salary) == 2:
                vacancy_salary_min = None
                vacancy_salary_max = (vacancy_salary[0].getText().replace(u'\xa0', u''))
                vacancy_salary_max = int(re.search('(?<=до).*?(?!\d)', vacancy_salary_max)[0])
            elif is_check_sarary == 'от':
                vacancy_salary_min = (vacancy_salary[0].getText().replace(u'\xa0', u''))
                vacancy_salary_min = int(re.search('(?<=от).*?(?!\d)', vacancy_salary_min)[0])
                vacancy_salary_max = None
            else:
                is_check_sarary1 = vacancy.find('span', {'class': 'f-test-text-company-item-salary'}) \
                                                .getText() \
                                                .replace(u'\xa0', u' ') \
                                                .split(' ')[2]
                if is_check_sarary1 == '—':  
                    vacancy_salary_min = (vacancy_salary[0].getText().replace(u'\xa0', u''))
                    vacancy_salary_min = int(re.search('.+?(?=—)', vacancy_salary_min)[0])
                
                    vacancy_salary_max = (vacancy_salary[0].getText().replace(u'\xa0', u'')) 
                    vacancy_salary_max = int(re.search('(?<=—).+?(?!\d)', vacancy_salary_max)[0])
                else:
                    vacancy_salary_min = (vacancy_salary[0].getText().replace(u'\xa0', u''))
                    vacancy_salary_min = int(re.search('.*?(?!\d)', vacancy_salary_min)[0])
                
                    vacancy_salary_max = vacancy_salary_min 
                            
        vacancy_data['name'] = vacancy_name
        vacancy_data['link'] = vacancy_link
        vacancy_data['salary_min'] = vacancy_salary_min
        vacancy_data['salary_max'] = vacancy_salary_max
        vacancy_data['salary_currency'] = vacancy_salary_currency
        vacancy_data['site'] = 'superjob.ru'

        vacancies.append(vacancy_data)
    return vacancies

# %%
sj_main_link = 'https://www.superjob.ru'
query = 'Python'
sj_page = 1
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:69.0) Gecko/20100101 Firefox/69.0'}

sj_vacancy_date = []


while True:
    sj_response = requests.get(sj_main_link + '/vacancy/search/?keywords=' + query + '&page=' + str(sj_page), headers=headers).text
    sj_soup = bs(sj_response,'lxml')
    
    sj_vacancy_date = sj_vacancy_date + parser_sj(sj_soup, sj_main_link)
    sj_page += 1
    if sj_soup.find('a',{'class':'f-test-button-dalshe'}) is None:
        break

# %%
vacancy_date = []
vacancy_date.extend(sj_vacancy_date)
vacancy_date.extend(hh_vacancy_date)
    
df = pd.DataFrame(vacancy_date)

# %%
df[50:80]
# Out:
#                                                  name  \
# 50                         Web-разработчик Full stack
# 51                    Team lead / Ведущий разработчик
# 52               Reverse Engineer / Вирусный аналитик
# 53                      Программист микроконтроллеров
# 54               ML/NLP Architect / ML/NLP Архитектор
# 55                         NLP Engineer / NLP инженер
# 56             Программист-разработчик python (midle)
# 57                                   Python Developer
# 58                                     Data Scientist
# 59                                    PHP программист
# 60                                Backend-разработчик
# 61                                       Team Lead DQ
# 62                                        Программист
# 63      Frontend-разработчик midle (React.js \ ExtJS)
# 64                               QA Automation (Java)
# 65              Старший специалист по тестированию ПО
# 66                            Senior Golang Developer
# 67        DevOps Support Engineer/Linux Administrator
# 68  Senior Software Engineer, Database Engineering...
# 69  Embedded Software Engineer (Communications Ser...
# 70                     Senior Data Warehouse Engineer
# 71          Аналитик данных / Data Analyst (Python/R)
# 72                              Python Data Scientist
# 73                        Программист на Python / С++
# 74                                 Программист Python
# 75                  Backend python/Django разработчик
# 76                 Python (Django) программист Junior
# 77  Python разработчик/программист (Junior/Middle ...
# 78                                 Разработчик Python
# 79                   Junior Machine Learning Engineer
#
#                                                  link  salary_min  salary_max  \
# 50  https://www.superjob.ru/vakansii/web-razrabotc...         NaN    200000.0
# 51  https://www.superjob.ru/vakansii/team-lead-339...         NaN    300000.0
# 52  https://www.superjob.ru/vakansii/reverse-engin...         NaN    300000.0
# 53  https://www.superjob.ru/vakansii/programmist-m...         NaN         NaN
# 54  https://www.superjob.ru/vakansii/ml-33788781.html    120000.0         NaN
# 55  https://www.superjob.ru/vakansii/nlp-engineer-...    120000.0         NaN
# 56  https://khimki.hh.ru/vacancy/37674249?query=Py...    100000.0    180000.0
# 57  https://khimki.hh.ru/vacancy/37279680?query=Py...         NaN         NaN
# 58  https://khimki.hh.ru/vacancy/37645302?query=Py...         NaN         NaN
# 59  https://khimki.hh.ru/vacancy/37678834?query=Py...    500000.0    700000.0
# 60  https://khimki.hh.ru/vacancy/37608790?query=Py...      2500.0         NaN
# 61  https://khimki.hh.ru/vacancy/35658086?query=Py...         NaN         NaN
# 62  https://khimki.hh.ru/vacancy/37538062?query=Py...         NaN         NaN
# 63  https://khimki.hh.ru/vacancy/37328608?query=Py...    100000.0    200000.0
# 64  https://khimki.hh.ru/vacancy/37647786?query=Py...         NaN         NaN
# 65  https://khimki.hh.ru/vacancy/37036702?query=Py...         NaN    150000.0
# 66  https://khimki.hh.ru/vacancy/37616656?query=Py...         NaN         NaN
# 67  https://khimki.hh.ru/vacancy/37142166?query=Py...         NaN         NaN
# 68  https://khimki.hh.ru/vacancy/36976348?query=Py...         NaN         NaN
# 69  https://khimki.hh.ru/vacancy/37634723?query=Py...         NaN         NaN
# 70  https://khimki.hh.ru/vacancy/37615686?query=Py...         NaN         NaN
# 71  https://khimki.hh.ru/vacancy/37603927?query=Py...    116000.0    175000.0
# 72  https://khimki.hh.ru/vacancy/37521387?query=Py...    150000.0         NaN
# 73  https://khimki.hh.ru/vacancy/37673701?query=Py...    140000.0    180000.0
# 74  https://khimki.hh.ru/vacancy/37565167?query=Py...    160000.0    200000.0
# 75  https://khimki.hh.ru/vacancy/37587367?query=Py...    120000.0    200000.0
# 76  https://khimki.hh.ru/vacancy/37576697?query=Py...     25000.0         NaN
# 77  https://khimki.hh.ru/vacancy/37500874?query=Py...     80000.0         NaN
# 78  https://khimki.hh.ru/vacancy/37522527?query=Py...    150000.0    170000.0
# 79  https://khimki.hh.ru/vacancy/37711158?query=Py...         NaN    140000.0
#
#    salary_currency         site
# 50            руб.  superjob.ru
# 51            руб.  superjob.ru
# 52            руб.  superjob.ru
# 53            None  superjob.ru
# 54            руб.  superjob.ru
# 55            руб.  superjob.ru
# 56            руб.        hh.ru
# 57            None        hh.ru
# 58            None        hh.ru
# 59             KZT        hh.ru
# 60             USD        hh.ru
# 61            None        hh.ru
# 62            None        hh.ru
# 63            руб.        hh.ru
# 64            None        hh.ru
# 65            руб.        hh.ru
# 66            None        hh.ru
# 67            None        hh.ru
# 68            None        hh.ru
# 69            None        hh.ru
# 70            None        hh.ru
# 71            руб.        hh.ru
# 72            руб.        hh.ru
# 73            руб.        hh.ru
# 74            руб.        hh.ru
# 75            руб.        hh.ru
# 76            руб.        hh.ru
# 77            руб.        hh.ru
# 78            руб.        hh.ru
# 79            руб.        hh.ru
